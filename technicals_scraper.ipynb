# %%
import os
import requests
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen, Request
from dotenv import load_dotenv
load_dotenv()
import pandas as pd
import matplotlib
# %matplotlib inline

# %% [markdown]
# # ETH Technicals Summary

# %%
# Setup a scraper for technical summary
url = ("http://www.investing.com/indices/investing.com-eth-usd")
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
html = soup(webpage, "html.parser")

# %%
# Obtain technical summary data
eth_technical_summary = pd.read_html(str(html), attrs = {'class': 'genTbl closedTbl technicalSummaryTbl'})[0]
eth_technical_summary
# Out:
#                    Type 5 Min      15 Min      Hourly       Daily     Monthly
# 0       Moving Averages   Buy         Buy         Buy         Buy  Strong Buy
# 1  Technical Indicators   BUY  Strong Buy  Strong Buy  Strong Buy  Strong Buy
# 2               Summary   Buy  Strong Buy  Strong Buy  Strong Buy  Strong Buy

# %%
# Obtain candelstick paterns
eth_candlestick_patterns = pd.read_html(str(html), attrs = {'class': 'genTbl closedTbl ecoCalTbl patternTable js-csp-table'})[0]
eth_candlestick_patterns = eth_candlestick_patterns.drop(columns='Pattern').rename(columns={'Pattern.1':'Pattern'})
eth_candlestick_patterns
# Out:
#                  Pattern           Timeframe         Reliability  \
# 0      Emerging Patterns   Emerging Patterns   Emerging Patterns
# 1           Harami Cross                  1M                 NaN
# 2     Completed Patterns  Completed Patterns  Completed Patterns
# 3      Engulfing Bearish                  30                 NaN
# 4      Bullish Engulfing                  1W                 NaN
# 5  Falling Three Methods                  5H                 NaN
#
#           Candles Ago           Candle Time
# 0   Emerging Patterns     Emerging Patterns
# 1             Current               Current
# 2  Completed Patterns    Completed Patterns
# 3                   2  Jul 28, 2021 06:30AM
# 4                   4          Jun 27, 2021
# 5                   4  Jul 27, 2021 11:00AM

# %% [markdown]
# # ETH Technicals (hourly)

# %%
# Setup a web scraper for ETH to pull technical indicators based on HOURLY data from Investing.com (working on pulling data for daily and monthly period)
url = ("http://www.investing.com/indices/investing.com-eth-usd-technical")
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
html = soup(webpage, "html.parser")

# %%
# Obtain data from the hourly Pivot points table
eth_pivot_points = pd.read_html(str(html), attrs = {'class': 'genTbl closedTbl crossRatesTbl'})[0]
eth_pivot_points
# Out:
#         Name       S3       S2       S1  Pivot Points       R1       R2  \
# 0    Classic  2278.06  2286.90  2294.01       2302.85  2309.95  2318.80
# 1  Fibonacci  2286.90  2292.99  2296.76       2302.85  2308.94  2312.71
# 2  Camarilla  2296.72  2298.18  2299.64       2302.85  2302.57  2304.03
# 3   Woodie's  2277.18  2286.46  2293.13       2302.41  2309.07  2318.36
# 4   DeMark's        -        -  2290.46       2301.07  2306.40        -
#
#         R3
# 0  2325.90
# 1  2318.80
# 2  2305.49
# 3  2325.02
# 4        -

# %%
# Obtain hourly technical data
eth_technicals = pd.read_html(str(html), attrs = {'class': 'genTbl closedTbl technicalIndicatorsTbl smallTbl float_lang_base_1', 'id':'curr_table'})[0]
eth_technicals
# Out:
#                                             Name  \
# 0                                        RSI(14)
# 1                                     STOCH(9,6)
# 2                                   STOCHRSI(14)
# 3                                    MACD(12,26)
# 4                                        ADX(14)
# 5                                    Williams %R
# 6                                        CCI(14)
# 7                                        ATR(14)
# 8                                 Highs/Lows(14)
# 9                            Ultimate Oscillator
# 10                                           ROC
# 11                           Bull/Bear Power(13)
# 12  Buy: 7 Sell: 0 Neutral: 1 Summary:Strong Buy
#
#                                            Value  \
# 0                                         62.723
# 1                                         52.482
# 2                                        100.000
# 3                                          9.540
# 4                                         36.800
# 5                                          0.000
# 6                                       270.1538
# 7                                        34.6021
# 8                                        33.1268
# 9                                         59.622
# 10                                         3.561
# 11                                       49.5813
# 12  Buy: 7 Sell: 0 Neutral: 1 Summary:Strong Buy
#
#                                           Action
# 0                                            Buy
# 1                                        Neutral
# 2                                     Overbought
# 3                                            Buy
# 4                                            Buy
# 5                                     Overbought
# 6                                     Overbought
# 7                                Less Volatility
# 8                                            Buy
# 9                                            Buy
# 10                                           Buy
# 11                                           Buy
# 12  Buy: 7 Sell: 0 Neutral: 1 Summary:Strong Buy

# %%
# Obtain moving averages based on hourly data
eth_moving_averages = pd.read_html(str(html), attrs = {'class':'genTbl closedTbl movingAvgsTbl float_lang_base_2','id':'curr_table'})[0]
eth_moving_averages
# Out:
#                         Period                       Simple  \
# 0                          MA5                  2305.31 Buy
# 1                         MA10                  2295.26 Buy
# 2                         MA20                  2278.68 Buy
# 3                         MA50                  2274.65 Buy
# 4                        MA100                  2217.14 Buy
# 5                        MA200                  2059.54 Buy
# 6  Buy: 12 Sell: 0 Summary:Buy  Buy: 12 Sell: 0 Summary:Buy
#
#                    Exponential
# 0                  2310.52 Buy
# 1                  2297.20 Buy
# 2                  2282.72 Buy
# 3                  2259.90 Buy
# 4                  2202.56 Buy
# 5                  2129.14 Buy
# 6  Buy: 12 Sell: 0 Summary:Buy

# %% [markdown]
# # BTC Technicals Summary

# %%
# Setup a scraper for technical summary
url = ("http://www.investing.com/indices/investing.com-btc-usd")
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
html = soup(webpage, "html.parser")

# %%
# Obtain technical summary data
btc_technical_summary = pd.read_html(str(html), attrs = {'class': 'genTbl closedTbl technicalSummaryTbl'})[0]
btc_technical_summary
# Out:
#                    Type       5 Min      15 Min      Hourly       Daily  \
# 0       Moving Averages         Buy         Buy         Buy         Buy
# 1  Technical Indicators  Strong Buy  Strong Buy  Strong Buy  Strong Buy
# 2               Summary  Strong Buy  Strong Buy  Strong Buy  Strong Buy
#
#       Monthly
# 0  Strong Buy
# 1  Strong Buy
# 2  Strong Buy

# %%
# Obtain candelstick paterns
btc_candlestick_patterns = pd.read_html(str(html), attrs = {'class': 'genTbl closedTbl ecoCalTbl patternTable js-csp-table'})[0]
btc_candlestick_patterns = btc_candlestick_patterns.drop(columns='Pattern').rename(columns={'Pattern.1':'Pattern'})
btc_candlestick_patterns
# Out:
#                  Pattern           Timeframe         Reliability  \
# 0      Emerging Patterns   Emerging Patterns   Emerging Patterns
# 1       Three Outside Up                  1W                 NaN
# 2     Completed Patterns  Completed Patterns  Completed Patterns
# 3      Doji Star Bearish                  5H                 NaN
# 4        Three Inside Up                  15                 NaN
# 5  Falling Three Methods                  30                 NaN
#
#           Candles Ago           Candle Time
# 0   Emerging Patterns     Emerging Patterns
# 1             Current               Current
# 2  Completed Patterns    Completed Patterns
# 3                   1  Jul 28, 2021 02:00AM
# 4                   3  Jul 28, 2021 06:45AM
# 5                   6  Jul 28, 2021 04:30AM

# %% [markdown]
# # BTC Technicals (hourly)

# %%
# Setup a web scraper for BTC to pull technical indicators based on HOURLY data from Investing.com (working on pulling data for daily and monthly period)
url = ("http://www.investing.com/indices/investing.com-btc-usd-technical")
req = Request(url,headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
html = soup(webpage, "html.parser")

# %%
# Obtain data from the hourly Pivot points table
btc_pivot_points = pd.read_html(str(html), attrs = {'class': 'genTbl closedTbl crossRatesTbl'})[0]
btc_pivot_points
# Out:
#         Name       S3       S2       S1  Pivot Points       R1       R2  \
# 0    Classic  39384.9  39597.3  39892.1       40104.5  40399.3  40611.7
# 1  Fibonacci  39597.3  39791.0  39910.7       40104.5  40298.3  40418.0
# 2  Camarilla  40047.6  40094.1  40140.6       40104.5  40233.6  40280.1
# 3   Woodie's  39426.3  39618.0  39933.5       40125.2  40440.7  40632.4
# 4   DeMark's        -        -  39998.4       40157.6  40505.6        -
#
#         R3
# 0  40906.5
# 1  40611.7
# 2  40326.5
# 3  40947.9
# 4        -

# %%
# Obtain hourly technical data
btc_technicals = pd.read_html(str(html), attrs = {'class': 'genTbl closedTbl technicalIndicatorsTbl smallTbl float_lang_base_1', 'id':'curr_table'})[0]
btc_technicals
# Out:
#                                             Name  \
# 0                                        RSI(14)
# 1                                     STOCH(9,6)
# 2                                   STOCHRSI(14)
# 3                                    MACD(12,26)
# 4                                        ADX(14)
# 5                                    Williams %R
# 6                                        CCI(14)
# 7                                        ATR(14)
# 8                                 Highs/Lows(14)
# 9                            Ultimate Oscillator
# 10                                           ROC
# 11                           Bull/Bear Power(13)
# 12  Buy: 8 Sell: 0 Neutral: 0 Summary:Strong Buy
#
#                                            Value  \
# 0                                         68.992
# 1                                         97.064
# 2                                         85.698
# 3                                        530.400
# 4                                         46.153
# 5                                         -0.460
# 6                                       192.7349
# 7                                       658.2201
# 8                                       710.7455
# 9                                         63.669
# 10                                         6.376
# 11                                     1549.8675
# 12  Buy: 8 Sell: 0 Neutral: 0 Summary:Strong Buy
#
#                                           Action
# 0                                            Buy
# 1                                     Overbought
# 2                                     Overbought
# 3                                            Buy
# 4                                            Buy
# 5                                     Overbought
# 6                                            Buy
# 7                                High Volatility
# 8                                            Buy
# 9                                            Buy
# 10                                           Buy
# 11                                           Buy
# 12  Buy: 8 Sell: 0 Neutral: 0 Summary:Strong Buy

# %%
# Obtain moving averages based on hourly data
btc_moving_averages = pd.read_html(str(html), attrs = {'class':'genTbl closedTbl movingAvgsTbl float_lang_base_2','id':'curr_table'})[0]
btc_moving_averages
# Out:
#                         Period                       Simple  \
# 0                          MA5                  40034.9 Buy
# 1                         MA10                  39921.2 Buy
# 2                         MA20                  39213.7 Buy
# 3                         MA50                  38438.5 Buy
# 4                        MA100                  36533.9 Buy
# 5                        MA200                  33879.3 Buy
# 6  Buy: 12 Sell: 0 Summary:Buy  Buy: 12 Sell: 0 Summary:Buy
#
#                    Exponential
# 0                  40181.1 Buy
# 1                  39833.9 Buy
# 2                  39341.5 Buy
# 3                  38256.9 Buy
# 4                  36806.5 Buy
# 5                  35190.9 Buy
# 6  Buy: 12 Sell: 0 Summary:Buy
