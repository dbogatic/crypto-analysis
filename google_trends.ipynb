# %% [markdown]
# # Pytrends
# ## Allows simple interface for automating downloading of reports from Google Trends
# https://pypi.org/project/pytrends/

# %%
from pytrends.request import TrendReq
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## ETH Google Trends

# %%
# Execute the TrendReq method by passing the host language (hl) and timezone (tz) parameters
pytrends = TrendReq(hl='en-US', tz=360)

# %%
# Build list of keywords
kw_list = ["ethereum"] 

# Build the payload
eth_coin_trends = pytrends.build_payload(kw_list, timeframe='2021-01-01 2021-07-21')

# %%
# Pull ETH Google trends daily data for the selected time period
eth_trends = pytrends.interest_over_time()

eth_trends.to_csv('resources/eth_google_trends/eth_google_trends.csv')

# %%
# Read in daily ETH Google Trends data from 2016-2021
eth_trends_2021 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends.csv', parse_dates=True, index_col='date')
eth_trends_2020 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_1.csv', parse_dates=True, index_col='date')
eth_trends_2020_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_2.csv', parse_dates=True, index_col='date')
eth_trends_2019 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_3.csv', parse_dates=True, index_col='date')
eth_trends_2019_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_4.csv', parse_dates=True, index_col='date')
eth_trends_2018 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_5.csv', parse_dates=True, index_col='date')
eth_trends_2018_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_6.csv', parse_dates=True, index_col='date')
eth_trends_2017 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_7.csv', parse_dates=True, index_col='date')
eth_trends_2017_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_8.csv', parse_dates=True, index_col='date')
eth_trends_2016 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_9.csv', parse_dates=True, index_col='date')
eth_trends_2016_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_google_trends/eth_google_trends_10.csv', parse_dates=True, index_col='date')

# %%
# Concat dataframes into one, keep only needed column and sort date index
eth_trends_combined = pd.concat([eth_trends_2016,eth_trends_2016_2,eth_trends_2017,eth_trends_2017_2,eth_trends_2018,eth_trends_2018_2,eth_trends_2019,eth_trends_2019_2,eth_trends_2020,eth_trends_2020_2,eth_trends_2021], axis=0)
eth_trends_combined = eth_trends_combined.drop(columns='isPartial')
eth_trends_combined = eth_trends_combined.sort_index()
eth_trends_combined.to_csv('resources/eth_google_trends/eth_trends_combined.csv')
eth_trends_combined.tail()
# Out:
#             ethereum
# date
# 2021-07-17        18
# 2021-07-18        19
# 2021-07-19        20
# 2021-07-20        23
# 2021-07-21        21

# %%
# Read in eth coin metrics from csv
eth_metrics = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/eth_annual_metrics/eth_metrics_1.csv', parse_dates=True, index_col="time")

# %%
# Pull ETH prices from csv file
eth_price = eth_metrics['PriceUSD']
eth_price.head()
# Out:
# time
# 2021-01-01 00:00:00+00:00     730.914321
# 2021-01-02 00:00:00+00:00     775.296622
# 2021-01-03 00:00:00+00:00     990.365325
# 2021-01-04 00:00:00+00:00    1030.318449
# 2021-01-05 00:00:00+00:00    1101.559814
# Name: PriceUSD, dtype: float64

# %%
# Plot ETH price vs Google trends
fig, ax = plt.subplots(figsize=(12,7))
plt.plot(eth_metrics['PriceUSD'], label ='ETH Price', color='r')
ax.set_ylabel('ETH Price ($)')
plt.xticks(rotation=45)
ax.legend(loc='upper left')
plt.grid()

ax2 = ax.twinx()
plt.plot(eth_trends['ethereum'], label='ETH Google Trends', color='b')
ax.set_title('ETH Price vs Google Trends')
ax2.set_ylabel('ETH Google Trends') 
ax2.legend(loc='upper right')

# %% [markdown]
# ## BTC Google Trends

# %%
# Build list of keywords
kw_list = ['bitcoin'] 

# Build the payload
btc_coin_trends = pytrends.build_payload(kw_list, timeframe='2021-01-01 2021-07-21')

# %%
# Pull BTC Google trends daily data for the selected time period
btc_trends = pytrends.interest_over_time()

btc_trends.to_csv('resources/btc_google_trends/btc_google_trends.csv')

# %%
# Read in daily BTC Google Trends data from 2010-2021
btc_trends_2021 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends.csv', parse_dates=True, index_col='date')
btc_trends_2020 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_1.csv', parse_dates=True, index_col='date')
btc_trends_2020_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_2.csv', parse_dates=True, index_col='date')
btc_trends_2019 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_3.csv', parse_dates=True, index_col='date')
btc_trends_2019_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_4.csv', parse_dates=True, index_col='date')
btc_trends_2018 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_5.csv', parse_dates=True, index_col='date')
btc_trends_2018_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_6.csv', parse_dates=True, index_col='date')
btc_trends_2017 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_7.csv', parse_dates=True, index_col='date')
btc_trends_2017_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_8.csv', parse_dates=True, index_col='date')
btc_trends_2016= pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_9.csv', parse_dates=True, index_col='date')
btc_trends_2016_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_10.csv', parse_dates=True, index_col='date')
btc_trends_2015 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_11.csv', parse_dates=True, index_col='date')
btc_trends_2015_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_12.csv', parse_dates=True, index_col='date')
btc_trends_2014 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_13.csv', parse_dates=True, index_col='date')
btc_trends_2014_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_14.csv', parse_dates=True, index_col='date')
btc_trends_2013 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_15.csv', parse_dates=True, index_col='date')
btc_trends_2013_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_16.csv', parse_dates=True, index_col='date')
btc_trends_2012 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_17.csv', parse_dates=True, index_col='date')
btc_trends_2012_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_18.csv', parse_dates=True, index_col='date')
btc_trends_2011 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_19.csv', parse_dates=True, index_col='date')
btc_trends_2011_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_20.csv', parse_dates=True, index_col='date')
btc_trends_2010 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_21.csv', parse_dates=True, index_col='date')
btc_trends_2010_2 = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_google_trends/btc_google_trends_22.csv', parse_dates=True, index_col='date')

# %%
# Concat dataframes into one, keep only needed column and sort date index
btc_trends_combined = pd.concat([btc_trends_2010, btc_trends_2010_2,btc_trends_2011, btc_trends_2011_2, btc_trends_2012, btc_trends_2012_2, btc_trends_2013, btc_trends_2013_2, btc_trends_2014, btc_trends_2014_2, btc_trends_2015, btc_trends_2015_2, btc_trends_2016, btc_trends_2016_2, btc_trends_2017, btc_trends_2017_2, btc_trends_2018, btc_trends_2018_2, btc_trends_2019, btc_trends_2019_2, btc_trends_2020, btc_trends_2020_2, btc_trends_2021], axis=0)

btc_trends_combined = btc_trends_combined.drop(columns='isPartial')
btc_trends_combined = btc_trends_combined.sort_index()
btc_trends_combined.to_csv('resources/btc_google_trends/btc_trends_combined.csv')
btc_trends_combined.tail()
# Out:
#             bitcoin
# date
# 2021-07-13       18
# 2021-07-14       18
# 2021-07-15       18
# 2021-07-16       18
# 2021-07-17       17

# %%
btc_metrics = pd.read_csv('/Users/draganbogatic/Documents/Fin_Tech/crypto-analysis/resources/btc_annual_metrics/btc_metrics_1.csv', parse_dates=True, index_col='time')
btc_metrics.tail()
# Out:
#                           asset  AdrActCnt  CapMVRVCur  CapMrktCurUSD  \
# time
# 2021-07-14 00:00:00+00:00   btc     817900    1.697935   6.151814e+11
# 2021-07-15 00:00:00+00:00   btc     828844    1.643649   5.947511e+11
# 2021-07-16 00:00:00+00:00   btc     764392    1.632215   5.900542e+11
# 2021-07-17 00:00:00+00:00   btc     640355    1.630400   5.918126e+11
# 2021-07-18 00:00:00+00:00   btc     651828    1.639258   5.948379e+11
#
#                                HashRate      NVTAdj      PriceUSD  \
# time
# 2021-07-14 00:00:00+00:00  1.213783e+08  114.337877  32798.284519
# 2021-07-15 00:00:00+00:00  9.139070e+07   71.134357  31707.690037
# 2021-07-16 00:00:00+00:00  1.070985e+08   81.211930  31455.717582
# 2021-07-17 00:00:00+00:00  1.018260e+08  108.230430  31547.951199
# 2021-07-18 00:00:00+00:00  9.787224e+07  123.714333  31707.703853
#
#                                 SplyCur   TxCnt  TxTfrValAdjUSD  VelCur1yr
# time
# ...

# %%
# Read in BTC price from the csv file
btc_price = btc_metrics['PriceUSD']
btc_price.tail()
# Out:
# time
# 2021-07-14 00:00:00+00:00    32798.284519
# 2021-07-15 00:00:00+00:00    31707.690037
# 2021-07-16 00:00:00+00:00    31455.717582
# 2021-07-17 00:00:00+00:00    31547.951199
# 2021-07-18 00:00:00+00:00    31707.703853
# Name: PriceUSD, dtype: float64

# %%
# Plot BTC price vs Google trends
fig, ax = plt.subplots(figsize=(12,7))
plt.plot(btc_metrics['PriceUSD'], label ='BTC Price', color='r')
ax.set_ylabel('BTC Price ($)')
plt.xticks(rotation=45)
ax.legend(loc='upper left')
plt.grid()

ax2 = ax.twinx()
plt.plot(btc_trends['bitcoin'], label='BTC Google Trends', color='b')
ax.set_title('BTC Price vs Google Trends')
ax2.set_ylabel('BTC Google Trends') 
ax2.legend(loc='upper right')
